# %% [markdown]
# `Modificación por Antonio Aristizábal: Se agrega un nuevo ejemplo para visualizar el muestreo al superar y no superar la frecuencia de Nyquist.`<br>
# __[Repositorio Github](https://github.com/Antonio0119/PDS_AntonioAristizabal)__

# %% [markdown]
# # Ejemplo 3. Muestro de una combinación de señales analógicas.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %%
f1 = 25     # Frecuencia de la señal 1
f2 = 150    # Frecuencia de la señal 2
f3 = 50     # Frecuencia de la señal 3
fs = 1e3    # Frecuencia de muestreo
t = np.arange(0, 0.1, 1/fs) # Vector de tiempo
signal = (3*np.cos(2*np.pi*f1*t)) + (100*np.sin(2*np.pi*f2*t)) - (np.cos(2*np.pi*f3*t)) # Sumade señales

# %%
# Grafica de la señal analógica
plt.figure()
plt.plot(t, signal)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid()
plt.show()

# %% [markdown]
# La señal anterior esta muestreada correctamente porque se usó una frecuencia de muestro superior a 2 veces la máxima que es 200Hz, o sea, mayor a 400Hz. Si se usa por ejemplo una frecuencia de muestreo de 100Hz, que es inferior a 400Hz que es la tasa de Nyquist mínima en este caso, la señal estaría mal muestreada como se muestra a continuación.

# %%
fs = 1e2    # Frecuencia de muestreo nueva
t = np.arange(0, 0.1, 1/fs) # Vector de tiempo
signal = (3*np.cos(2*np.pi*f1*t)) + (100*np.sin(2*np.pi*f2*t)) - (np.cos(2*np.pi*f3*t)) # Suma de señales

# %%
# Grafica de la señal analógica
plt.figure()
plt.plot(t, signal)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid()
plt.show()

# %% [markdown]
# **Nuevo ejemplo de señal:**

# %%
f1 = 50     # Frecuencia de la señal 1
f2 = 150    # Frecuencia de la señal 2
f3 = 200     # Frecuencia de la señal 3
fs = 1e3    # Frecuencia de muestreo
t = np.arange(0, 0.1, 1/fs) # Vector de tiempo
signal = (2*np.cos(2*np.pi*f1*t)) - (30*np.sin(2*np.pi*f2*t)) - (15*np.cos(2*np.pi*f3*t)) # Suma de señales

# %%
# Grafica de la señal analógica
plt.figure()
plt.plot(t, signal)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Señal analógica con tasa de Nyquist mínima')
plt.grid()
plt.show()

# %%
fs = 1e2    # Frecuencia de muestreo nueva
t = np.arange(0, 0.1, 1/fs) # Vector de tiempo
signal = (2*np.cos(2*np.pi*f1*t)) - (30*np.sin(2*np.pi*f2*t)) - (15*np.cos(2*np.pi*f3*t)) # Suma de señales

# %%
# Grafica de la señal analógica
plt.figure()
plt.plot(t, signal)
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.title('Señal analógica sin tasa de Nyquist mínima')
plt.grid()
plt.show()
