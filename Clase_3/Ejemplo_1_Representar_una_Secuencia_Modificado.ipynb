# %% [markdown]
# `Modificación por Antonio Aristizábal: Se añade un ejemplo con una nueva secuencia.`<br>
# __[Repositorio Github](https://github.com/Antonio0119/PDS_AntonioAristizabal)__

# %% [markdown]
# # Ejemplo 1. Representar una secuencia.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %%
x_n = [1, 4, 3, 0, 4, 2, 3, 4, 0, 1, 4] # Secuencia
n = np.arange(len(x_n))                 # Vector de muestras

# %%
# Grafica de la secuencia
plt.figure()
plt.stem(n, x_n)
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')
plt.grid()
plt.show()

# %% [markdown]
# **Otro ejemplo de representación de una secuencia:**

# %%
x_n = [10, -6, 5, -3, 2.5, -1.5, 1, -1.5, 2.5, -3, 5, -6, 10] # Secuencia
n = np.arange(len(x_n))                 # Vector de muestras

# %%
# Grafica de la secuencia
plt.figure()
plt.stem(n, x_n)
plt.xlabel('Numero de muestras')
plt.ylabel('Amplitud')
plt.grid()
plt.show()
