# %% [markdown]
# `Modificación por Antonio Aristizábal: Se agrega un nuevo ejemplo de digitalización de señal analógica.`<br>
# __[Repositorio Github](https://github.com/Antonio0119/PDS_AntonioAristizabal)__

# %% [markdown]
# # Ejemplo 1. Digitalización de señales analógicas.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 2*np.pi, 20) # Vector de tiempo
signal = np.sin(t)              # Señal analogica

# %%
# Grafica de la señal analógica y digital
plt.figure()
plt.plot(t, signal, 'b', label = 'Señal analógica')
plt.stem(t, signal, 'r', label = 'Señal digitalizada')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **Nuevo ejemplo de digitalización de señales analógicas:**

# %%
t = np.linspace(0, 2*np.pi, 30) # Vector de tiempo
signal = 10*np.cos(30*t)+5      # Señal analogica

# %%
# Grafica de la señal analógica y digital
plt.figure()
plt.plot(t, signal, 'b', label = 'Señal analógica 10cos(30t)+5')
plt.stem(t, signal, 'g', label = 'Señal digitalizada')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.grid()
plt.legend()
plt.title('Señal Analógica Digitalizada')
plt.show()
